-- %%
USE CATALOG workspace;
USE SCHEMA default;

-- %%
CREATE OR REPLACE VIEW dim_customer AS
SELECT * FROM delta.`s3://s3-databrick-warehouse/gold/dim_customer/`;

-- %%
select  * from dim_customer;

-- %%
desc  dim_customer;
