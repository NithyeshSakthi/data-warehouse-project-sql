-- %%
USE CATALOG workspace;
USE SCHEMA default;

-- %%
CREATE OR REPLACE VIEW fact_sales AS
SELECT * FROM delta.`s3://s3-databrick-warehouse/gold/fact_sales/`;

-- %%
select  * from fact_sales;

-- %%
describe fact_sales;
