-- %%
USE CATALOG workspace;
USE SCHEMA default;

-- %%
CREATE OR REPLACE VIEW dim_products AS
SELECT * FROM delta.`s3://s3-databrick-warehouse/gold/dim_products/`;

-- %%
select  * from dim_products;

-- %%
desc dim_products;
